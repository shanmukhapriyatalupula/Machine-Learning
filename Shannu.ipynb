# %% [markdown]
# <a href="https://colab.research.google.com/github/shanmukhapriyatalupula/Machine-Learning/blob/main/Shannu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # **ARITHMETIC OPERATIONS**

# %%
a=np.array([[5,10,15],[20,25,35]])
print(a)
# Out:
# [[ 5 10 15]
#  [20 25 35]]

# %%
b=np.array([[40,45,50],[55,60,25]])
print(b)
# Out:
# [[40 45 50]
#  [55 60 25]]

# %%
np.add(a,b)
# Out:
# array([[45, 55, 65],
#        [75, 85, 60]])

# %%
np.subtract(a,b)
# Out:
# array([[-35, -35, -35],
#        [-35, -35,  10]])

# %%
np.multiply(a,b)
# Out:
# array([[ 200,  450,  750],
#        [1100, 1500,  875]])

# %%
np.divide(a,b)
# Out:
# array([[0.125     , 0.22222222, 0.3       ],
#        [0.36363636, 0.41666667, 1.4       ]])

# %%
np.exp(a)
# Out:
# array([[1.48413159e+02, 2.20264658e+04, 3.26901737e+06],
#        [4.85165195e+08, 7.20048993e+10, 1.58601345e+15]])

# %%
np.exp(b)
# Out:
# array([[2.35385267e+17, 3.49342711e+19, 5.18470553e+21],
#        [7.69478527e+23, 1.14200739e+26, 7.20048993e+10]])

# %%
np.sqrt(a)
# Out:
# array([[2.23606798, 3.16227766, 3.87298335],
#        [4.47213595, 5.        , 5.91607978]])

# %%
np.sqrt(b)
# Out:
# array([[6.32455532, 6.70820393, 7.07106781],
#        [7.41619849, 7.74596669, 5.        ]])

# %%
b[1][0]=20
b[1][1]=25
b[1][2]=35

# %%
b
# Out:
# array([[40, 45, 50],
#        [20, 25, 35]])

# %%
a==b
# Out:
# <ipython-input-47-a6f7ccb4d5ba>:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   a==b
# False

# %% [markdown]
# # **ARRAY OPERATIONS**

# %%
a=np.array([[100,200],[300,400],[500,600]])
print(a)
# Out:
# [[100 200]
#  [300 400]
#  [500 600]]

# %%
np.sum(a)
# Out:
# 2100

# %%
np.min(a)
# Out:
# 100

# %%
np.min(a,axis=1)
# Out:
# array([100, 300, 500])

# %%
np.max(a,axis=0)
# Out:
# array([500, 600])

# %%
np.mean(a,axis=0)
# Out:
# array([300., 400.])

# %%
np.median(a,axis=1)
# Out:
# array([150., 350., 550.])

# %%
np.var(a,axis=0)
# Out:
# array([26666.66666667, 26666.66666667])

# %%
np.std(a,axis=1)
# Out:
# array([50., 50., 50.])

# %%
np.std(a)
# Out:
# 170.78251276599332

# %% [markdown]
# # **PAIRWISE PLOTS**

# %%
from ast import increment_lineno
import seaborn as sns
# %matplotlib inline
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue="time")

# %%
sns.pairplot(tips,hue="smoker")

# %% [markdown]
# # **HEATMAPS**

# %%
flights=sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
x=flights.pivot_table(index="year",columns="month",values="passengers",aggfunc="sum")
x
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(x)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,cbar=False)
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidth=0.5,annot=True,fmt="d")
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidth=0.5,annot=True,fmt="d",cmap="viridis")
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidth=0.5,annot=True,fmt="d",cmap="summer")
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
sns.heatmap(x,linewidth=0.5,annot=True,fmt="d",cmap="winter")
# Out:
# <Axes: xlabel='month', ylabel='year'>
